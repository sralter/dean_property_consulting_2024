# %% [markdown]
# # Dean Property Consulting 2024

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Begin EDA

# %%
# global variables for the visualizations
color='coral'
figsize=(7.5,7.5)

# %%
# read in dataset
df=pd.read_csv('../data/230000 RE Transfers 2010-2023 PROGRESS SORTED 2.csv',low_memory=False)

# %%
# peek at a sample
df.sample(5)
# Out:
#       Unnamed: 0        DATE NEIGBORHOOD   No.        STREET    ZIP  \
# 39510        NaN  08/01/2023         NaN   NaN           NaN    NaN
# 26852        NaN  06/05/2020         NaN   101   Douglass St  11231
# 12926        NaN  06/21/2016         NaN  1776       72nd St  11204
# 39566        NaN  08/03/2023         NaN   NaN           NaN    NaN
# 5196         NaN  06/18/2014         NaN   978  East 24th St  11210
#
#           SALE / ASK                           WEB RENT ROLL UNITS  ...  TAX  \
# 39510  $1,900,000.00  124 15th St, Brooklyn, 11215       NaN     3  ...  NaN
# 26852  $3,100,000.00        101 Douglass St, 11231       NaN     6  ...  NaN
# 12926  $1,400,000.00                           NaN       NaN     4  ...  NaN
# 39566  $1,538,000.00  35 Bay 8 St, Brooklyn, 11228       NaN     2  ...  NaN
# 5196   $1,600,000.00                           NaN       NaN     1  ...  NaN
#
#       BEDS BATHS WEEKS      TELEPHONE CONTACT AGENCY    ANNUAL $   30yr  \
# 39510  NaN   NaN   NaN            NaN     NaN    NaN  $98,110.00   6.9%
# 26852  NaN   NaN   NaN  PropertyShark     NaN    NaN  $77,133.00  3.21%
# 12926  NaN   NaN   NaN  PropertyShark     NaN    NaN  $38,501.00  3.56%
# 39566  NaN   NaN   NaN            NaN     NaN    NaN  $79,418.00   6.9%
# 5196   NaN   NaN    12  PropertyShark     NaN    NaN  $52,300.00  4.26%
#
#         ZONING
# 39510      R6B
# 26852      R6B
# 12926  C1-2/R5
# 39566       R4
# 5196       NaN
#
# [5 rows x 31 columns]

# %%
df.tail(10)
# Out:
#       Unnamed: 0        DATE NEIGBORHOOD  No. STREET  ZIP     SALE / ASK  \
# 40681        NaN  12/14/2023         NaN  NaN    NaN  NaN    $690,000.00
# 40682        NaN  12/14/2023         NaN  NaN    NaN  NaN    $850,000.00
# 40683        NaN  12/14/2023         NaN  NaN    NaN  NaN  $1,120,000.00
# 40684        NaN         NaN         NaN  NaN    NaN  NaN            NaN
# 40685        NaN         NaN         NaN  NaN    NaN  NaN            NaN
# 40686        NaN         NaN         NaN  NaN    NaN  NaN            NaN
# 40687        NaN         NaN         NaN  NaN    NaN  NaN            NaN
# 40688        NaN         NaN         NaN  NaN    NaN  NaN            NaN
# 40689        NaN         NaN         NaN  NaN    NaN  NaN            NaN
# 40690        NaN         NaN         NaN  NaN    NaN  NaN            NaN
#
#                                        WEB RENT ROLL UNITS  ...  TAX BEDS  \
# 40681        1670 73rd St, Brooklyn, 11204       NaN     1  ...  NaN  NaN
# 40682  7415 Tenth Ave #1C, Brooklyn, 11228       NaN     1  ...  NaN  NaN
# 40683     168 Bleecker St, Brooklyn, 11221       NaN     6  ...  NaN  NaN
# 40684                                  NaN       NaN   NaN  ...  NaN  NaN
# 40685                                  NaN       NaN   NaN  ...  NaN  NaN
# 40686                                  NaN       NaN   NaN  ...  NaN  NaN
# 40687                                  NaN       NaN   NaN  ...  NaN  NaN
# 40688                                  NaN       NaN   NaN  ...  NaN  NaN
# 40689                                  NaN       NaN   NaN  ...  NaN  NaN
# 40690                                  NaN       NaN   NaN  ...  NaN  NaN
#
#       BATHS WEEKS TELEPHONE CONTACT AGENCY    ANNUAL $   30yr ZONING
# 40681   NaN   NaN       NaN     NaN    NaN  $35,871.00  6.95%     R5
# 40682   NaN   NaN       NaN     NaN    NaN  $44,189.00  6.95%    R5B
# 40683   NaN   NaN       NaN     NaN    NaN  $58,225.00  6.95%     R6
# 40684   NaN   NaN       NaN     NaN    NaN       $0.00    NaN    NaN
# 40685   NaN   NaN       NaN     NaN    NaN       $0.00    NaN    NaN
# 40686   NaN   NaN       NaN     NaN    NaN       $0.00    NaN    NaN
# 40687   NaN   NaN       NaN     NaN    NaN       $0.00    NaN    NaN
# 40688   NaN   NaN       NaN     NaN    NaN       $0.00    NaN    NaN
# 40689   NaN   NaN       NaN     NaN    NaN       $0.00    NaN    NaN
# 40690   NaN   NaN       NaN     NaN    NaN       $0.00    NaN    NaN
#
# [10 rows x 31 columns]

# %%
# remove the bottom 7 rows as they're blank data
df=df[:-7]
df.tail()
# Out:
#       Unnamed: 0        DATE NEIGBORHOOD  No. STREET  ZIP     SALE / ASK  \
# 40679        NaN  12/14/2023         NaN  NaN    NaN  NaN    $470,000.00
# 40680        NaN  12/14/2023         NaN  NaN    NaN  NaN  $2,220,000.00
# 40681        NaN  12/14/2023         NaN  NaN    NaN  NaN    $690,000.00
# 40682        NaN  12/14/2023         NaN  NaN    NaN  NaN    $850,000.00
# 40683        NaN  12/14/2023         NaN  NaN    NaN  NaN  $1,120,000.00
#
#                                        WEB RENT ROLL UNITS  ...  TAX BEDS  \
# 40679      752 Rutland Rd, Brooklyn, 11203       NaN     2  ...  NaN  NaN
# 40680     722 Chauncey St, Brooklyn, 11207       NaN     1  ...  NaN  NaN
# 40681        1670 73rd St, Brooklyn, 11204       NaN     1  ...  NaN  NaN
# 40682  7415 Tenth Ave #1C, Brooklyn, 11228       NaN     1  ...  NaN  NaN
# 40683     168 Bleecker St, Brooklyn, 11221       NaN     6  ...  NaN  NaN
#
#       BATHS WEEKS TELEPHONE CONTACT AGENCY     ANNUAL $   30yr ZONING
# 40679   NaN   NaN       NaN     NaN    NaN   $24,434.00  6.95%     R6
# 40680   NaN   NaN       NaN     NaN    NaN  $115,411.00  6.95%     R6
# 40681   NaN   NaN       NaN     NaN    NaN   $35,871.00  6.95%     R5
# 40682   NaN   NaN       NaN     NaN    NaN   $44,189.00  6.95%    R5B
# 40683   NaN   NaN       NaN     NaN    NaN   $58,225.00  6.95%     R6
#
# [5 rows x 31 columns]

# %%
# check information about dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40684 entries, 0 to 40683
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   187 non-null    object
#  1   DATE         40684 non-null  object
#  2   NEIGBORHOOD  1753 non-null   object
#  3   No.          33735 non-null  object
#  4   STREET       33735 non-null  object
#  5   ZIP          33405 non-null  object
#  6   SALE / ASK   40682 non-null  object
#  7   WEB          17352 non-null  object
#  8   RENT ROLL    7548 non-null   object
#  9   UNITS        40656 non-null  object
#  10  FLOORS       40675 non-null  object
#  11  LEGAL        39920 non-null  object
#  12  STRUCTURE    20986 non-null  object
#  13  C            927 non-null    object
#  14  LOT 1        28936 non-null  object
#  15  LOT 2        34403 non-null  object
#  16  SF           40670 non-null  object
#  17  $/SF         39776 non-null  object
#  18  SF/FLOOR     39619 non-null  object
#  19  $/FLOOR      40119 non-null  object
#  20  CHARGES      171 non-null    object
#  21  TAX          957 non-null    object
#  22  BEDS         819 non-null    object
#  23  BATHS        828 non-null    float64
#  24  WEEKS        10753 non-null  object
#  25  TELEPHONE    37110 non-null  object
#  26  CONTACT      198 non-null    object
#  27  AGENCY       529 non-null    object
#  28  ANNUAL $     40602 non-null  object
#  29  30yr         40359 non-null  object
#  30  ZONING       32547 non-null  object
# dtypes: float64(1), object(30)
# memory usage: 9.6+ MB

# %% [markdown]
# Convert some columns to appropriate data types.

# %%
# convert date column to correct format
df['DATE']=pd.to_datetime(df['DATE'])

# SALE / ASK column
# remove dollar symbol 
# convert to number data type
df['SALE / ASK']=df['SALE / ASK'].str.replace(r'[\$,]', '', regex=True)
df['SALE / ASK']=df['SALE / ASK'].astype('float64')

# recheck
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40684 entries, 0 to 40683
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   187 non-null    object
#  1   DATE         40684 non-null  datetime64[ns]
#  2   NEIGBORHOOD  1753 non-null   object
#  3   No.          33735 non-null  object
#  4   STREET       33735 non-null  object
#  5   ZIP          33405 non-null  object
#  6   SALE / ASK   40682 non-null  float64
#  7   WEB          17352 non-null  object
#  8   RENT ROLL    7548 non-null   object
#  9   UNITS        40656 non-null  object
#  10  FLOORS       40675 non-null  object
#  11  LEGAL        39920 non-null  object
#  12  STRUCTURE    20986 non-null  object
#  13  C            927 non-null    object
#  14  LOT 1        28936 non-null  object
#  15  LOT 2        34403 non-null  object
#  16  SF           40670 non-null  object
#  17  $/SF         39776 non-null  object
#  18  SF/FLOOR     39619 non-null  object
#  19  $/FLOOR      40119 non-null  object
#  20  CHARGES      171 non-null    object
#  21  TAX          957 non-null    object
#  22  BEDS         819 non-null    object
#  23  BATHS        828 non-null    float64
#  24  WEEKS        10753 non-null  object
#  25  TELEPHONE    37110 non-null  object
#  26  CONTACT      198 non-null    object
#  27  AGENCY       529 non-null    object
#  28  ANNUAL $     40602 non-null  object
#  29  30yr         40359 non-null  object
#  30  ZONING       32547 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(28)
# memory usage: 9.6+ MB

# %%
# quick statistical information
# this will throw error
# but we can still have a look
df['DATE'].describe()
# Out:
# /var/folders/n3/q8wb235x57n_sx2q14dsngjr0000gn/T/ipykernel_62878/550326953.py:4: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df['DATE'].describe()
# count                   40684
# unique                   2914
# top       2012-01-12 00:00:00
# freq                       97
# first     2010-01-03 00:00:00
# last      2023-12-14 00:00:00
# Name: DATE, dtype: object

# %%
# curious about the Unnamed column
df['Unnamed: 0'].value_counts()
# Out:
# A    78
# O    50
# P    45
# X    11
# C     3
# Name: Unnamed: 0, dtype: int64

# %% [markdown]
# The `Unnamed` column is something to talk about with the client as it may represent domain-specific knowledge.

# %%
df['SALE / ASK'].describe()
# Out:
# count    4.068200e+04
# mean     1.405476e+06
# std      1.635294e+06
# min      0.000000e+00
# 25%      7.500000e+05
# 50%      1.100000e+06
# 75%      1.625000e+06
# max      1.020000e+08
# Name: SALE / ASK, dtype: float64

# %%
df['SALE / ASK'].value_counts()
# Out:
# 1200000.0    613
# 1300000.0    558
# 1100000.0    525
# 1250000.0    434
# 950000.0     431
#             ...
# 1537609.0      1
# 1494000.0      1
# 415200.0       1
# 6129000.0      1
# 1366000.0      1
# Name: SALE / ASK, Length: 5593, dtype: int64

# %%
(df['SALE / ASK'].isna().sum()/df['SALE / ASK'].count())*100
# Out:
# 0.004916179145568064

# %%
df[df['SALE / ASK'].isnull()]
# Out:
#       Unnamed: 0       DATE        NEIGBORHOOD  No.          STREET  ZIP  \
# 13579          X 2016-08-21        Fort Greene  111  Vanderbilt Ave  NaN
# 13654          X 2016-08-28  Downtown Brooklyn  388       Bridge St  NaN
#
#        SALE / ASK  WEB RENT ROLL UNITS  ...        TAX BEDS BATHS WEEKS  \
# 13579         NaN  NaN       NaN     1  ...  $6,348.00    2   1.5    10
# 13654         NaN  NaN       NaN     1  ...    $972.00    3   2.0     2
#
#            TELEPHONE CONTACT           AGENCY    ANNUAL $   30yr ZONING
# 13579  PropertyShark     NaN  Douglas Elliman  $13,356.00  3.43%    NaN
# 13654  PropertyShark     NaN         Halstead  $21,888.00  3.43%    NaN
#
# [2 rows x 31 columns]

# %% [markdown]
# There are two sale prices missing. Out of the entire dataset, that equates to 0.0049% of the entire dataset.

# %%
# define the two rows
rows_to_remove = [13579, 13654]

# drop the two rows
df.drop(rows_to_remove, inplace=True)

# check work
df[df['SALE / ASK'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, DATE, NEIGBORHOOD, No., STREET, ZIP, SALE / ASK, WEB, RENT ROLL, UNITS, FLOORS, LEGAL, STRUCTURE, C, LOT 1, LOT 2, SF, $/SF, SF/FLOOR, $/FLOOR, CHARGES, TAX, BEDS, BATHS, WEEKS, TELEPHONE, CONTACT, AGENCY, ANNUAL $, 30yr, ZONING]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# Let's plot the distribution of sale prices.

# %% [markdown]
# #### Visualization of `Sale/Ask` Prices

# %%
# explore bin sizes

bin_number=10

# extract column
data = df['SALE / ASK']

# Compute the histogram with 10 bins
hist, bin_edges = np.histogram(data, bins=bin_number)

# The bin_edges variable contains the edges of the bins
bin_categories = [(bin_edges[i], bin_edges[i+1]) for i in range(len(bin_edges)-1)]
print(bin_categories)
# Out:
# [(0.0, 10200000.0), (10200000.0, 20400000.0), (20400000.0, 30600000.0), (30600000.0, 40800000.0), (40800000.0, 51000000.0), (51000000.0, 61200000.0), (61200000.0, 71400000.0), (71400000.0, 81600000.0), (81600000.0, 91800000.0), (91800000.0, 102000000.0)]

# %%
plt.figure(figsize=(10,10))
plt.hist(df['SALE / ASK'], 
         bins=20, 
         color='coral',
         edgecolor='black')
plt.xticks()
plt.xlabel('Price/Ask')
plt.ylabel('Count')
plt.title('Histogram of Sale/Ask Prices ($)')
plt.show()

# %% [markdown]
# The vast majority of the sales are below $10,000,000.

# %%
.1e8
# Out:
# 10000000.0

# %% [markdown]
# What about for sales below $10,000,000?

# %%
# filter the dataset
b10m=df[df['SALE / ASK']<1e7]

# check
b10m['SALE / ASK'].describe()
# Out:
# count    4.058900e+04
# mean     1.361563e+06
# std      1.037202e+06
# min      0.000000e+00
# 25%      7.500000e+05
# 50%      1.100000e+06
# 75%      1.611989e+06
# max      9.907500e+06
# Name: SALE / ASK, dtype: float64

# %%
plt.figure(figsize=figsize)
plt.hist(b10m['SALE / ASK'], 
         bins=20, 
         color=color,
         edgecolor='black')
# plt.xticks(ticks=[0,'2,000,000','4,000,000','6,000,000','8,000,000','10,000,000'])
plt.xlabel('Price/Ask')
plt.ylabel('Count')
plt.title('Histogram of Sale/Ask Prices ($)\nFor Sales Below $10,000,000')
plt.savefig('../figs/hist_salesbelow1e7.pdf',bbox_inches='tight')
plt.savefig('../figs/hist_salesbelow1e7.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Visualization of other categories

# %% [markdown]
# Let's do some more visualizations. But first, we'll look at the whole table again.

# %%
df.head(3)
# Out:
#   Unnamed: 0       DATE       NEIGBORHOOD  No.         STREET  ZIP  \
# 0        NaN 2010-01-03       Ditmas Park  657   East 24th St  NaN
# 1        NaN 2010-01-06       Boerum Hill  229        Dean St  NaN
# 2        NaN 2010-01-10  Brooklyn Heights   38  Livingston St  NaN
#
#    SALE / ASK  WEB RENT ROLL UNITS  ...    TAX BEDS BATHS WEEKS    TELEPHONE  \
# 0    770000.0  NaN       NaN     1  ...  3,753    6   3.0    12      NYTimes
# 1   1397478.0  NaN       NaN     2  ...  4,617    4   2.0    12  Brownstoner
# 2    505000.0  NaN       NaN     1  ...      1    1   1.0     2      NYTimes
#
#   CONTACT                        AGENCY    ANNUAL $   30yr ZONING
# 0     NaN   Coldwell Banker Residential  $36,033.00  5.53%    NaN
# 1     NaN                           NaN  $63,202.00  5.53%    NaN
# 2     NaN  Brooklyn Heights Real Estate  $30,089.00  5.61%    NaN
#
# [3 rows x 31 columns]

# %% [markdown]
# We need to confirm that the rest of the dataset is in appropriate datatypes.

# %%
# list all the columns and their description
for col in df.columns:
    print(f'''
{col}\n
{df[col].describe()}\n
{df[col].sample(3)}\n
**********
    ''')
# Out:
# Unnamed: 0
#
# count     185
# unique      5
# top         A
# freq       78
# Name: Unnamed: 0, dtype: object
#
# 10445    NaN
# 18181    NaN
# 32530    NaN
# Name: Unnamed: 0, dtype: object
#
# **********
#
#
# DATE
#
# count                   40682
# unique                   2912
# top       2012-01-12 00:00:00
# freq                       97
# first     2010-01-03 00:00:00
# last      2023-12-14 00:00:00
# Name: DATE, dtype: object
#
# 22598   2019-01-04
# 26328   2020-03-10
# 21579   2018-09-21
# Name: DATE, dtype: datetime64[ns]
#
# **********
#
#
# NEIGBORHOOD
#
# count           1751
# unique            54
# top       Park Slope
# freq             315
# Name: NEIGBORHOOD, dtype: object
#
# 37980    NaN
# 8511     NaN
# 33618    NaN
# Name: NEIGBORHOOD, dtype: object
#
# **********
#
#
# No.
#
# count     33733
# unique     3796
# top         111
# freq        104
# Name: No., dtype: object
#
# 35351    NaN
# 40400    NaN
# 40489    NaN
# Name: No., dtype: object
#
# **********
#
#
# STREET
#
# count             33733
# unique              914
# top       Jefferson Ave
# freq                394
# Name: STREET, dtype: object
#
# 9023         19th St
# 22204    Humboldt St
# 20346        73rd St
# Name: STREET, dtype: object
#
# **********
#
#
# ZIP
#
# count     33405
# unique       37
# top       11221
# freq       3128
# Name: ZIP, dtype: object
#
# 26413    11238
# 17206    11220
# 7640     11215
# Name: ZIP, dtype: object
#
# **********
#
#
# SALE / ASK
#
# count    4.068200e+04
# mean     1.405476e+06
# std      1.635294e+06
# min      0.000000e+00
# 25%      7.500000e+05
# 50%      1.100000e+06
# 75%      1.625000e+06
# max      1.020000e+08
# Name: SALE / ASK, dtype: float64
#
# 8266     1075000.0
# 24082    1775000.0
# 4242      525000.0
# Name: SALE / ASK, dtype: float64
#
# **********
#
#
# WEB
#
# count                                     17352
# unique                                    16917
# top       244-276 Bay 19 St #A, Brooklyn, 11214
# freq                                          5
# Name: WEB, dtype: object
#
# 16987                               NaN
# 37183    285 E 16th St, Brooklyn, 11226
# 46                                  NaN
# Name: WEB, dtype: object
#
# **********
#
#
# RENT ROLL
#
# count     7548
# unique     597
# top         #2
# freq       508
# Name: RENT ROLL, dtype: object
#
# 25977    NaN
# 9286     NaN
# 13747    NaN
# Name: RENT ROLL, dtype: object
#
# **********
#
#
# UNITS
#
# count     40654
# unique       65
# top           1
# freq      14579
# Name: UNITS, dtype: object
#
# 19143    3
# 22060    1
# 29041    2
# Name: UNITS, dtype: object
#
# **********
#
#
# FLOORS
#
# count     40673
# unique       37
# top           2
# freq      16368
# Name: FLOORS, dtype: object
#
# 7784       4
# 14276      4
# 18217    2.5
# Name: FLOORS, dtype: object
#
# **********
#
#
# LEGAL
#
# count     39918
# unique       90
# top           2
# freq       8249
# Name: LEGAL, dtype: object
#
# 36466    Walk-up Cooperative (C6)
# 9799                            2
# 34738    Walk-up Cooperative (C6)
# Name: LEGAL, dtype: object
#
# **********
#
#
# STRUCTURE
#
# count     20986
# unique       70
# top       brick
# freq       3650
# Name: STRUCTURE, dtype: object
#
# 9493     converted from one family
# 26513                      walk-up
# 23907                        frame
# Name: STRUCTURE, dtype: object
#
# **********
#
#
# C
#
# count     927
# unique      2
# top         G
# freq      645
# Name: C, dtype: object
#
# 32033    NaN
# 1577     NaN
# 10380    NaN
# Name: C, dtype: object
#
# **********
#
#
# LOT 1
#
# count     28936
# unique      598
# top          20
# freq       8467
# Name: LOT 1, dtype: object
#
# 6426     80
# 4823     40
# 25936    25
# Name: LOT 1, dtype: object
#
# **********
#
#
# LOT 2
#
# count     34403
# unique     3437
# top         100
# freq      12468
# Name: LOT 2, dtype: object
#
# 4390     NaN
# 3406     100
# 17255     25
# Name: LOT 2, dtype: object
#
# **********
#
#
# SF
#
# count     40668
# unique     5229
# top           0
# freq        892
# Name: SF, dtype: object
#
# 1187     2,815
# 40       4,664
# 38364    2,760
# Name: SF, dtype: object
#
# **********
#
#
# $/SF
#
# count       39774
# unique       2119
# top       $500.00
# freq          106
# Name: $/SF, dtype: object
#
# 17129    $1,007.00
# 15091      $747.00
# 12557      $359.00
# Name: $/SF, dtype: object
#
# **********
#
#
# SF/FLOOR
#
# count     39617
# unique     2542
# top       1,200
# freq        814
# Name: SF/FLOOR, dtype: object
#
# 17587    303
# 1668     800
# 33292    NaN
# Name: SF/FLOOR, dtype: object
#
# **********
#
#
# $/FLOOR
#
# count           40117
# unique           7445
# top       $600,000.00
# freq              466
# Name: $/FLOOR, dtype: object
#
# 26957    $620,000.00
# 26118    $990,000.00
# 26168    $415,500.00
# Name: $/FLOOR, dtype: object
#
# **********
#
#
# CHARGES
#
# count         169
# unique        151
# top        \t-
# freq            4
# Name: CHARGES, dtype: object
#
# 11707    NaN
# 270      NaN
# 37920    NaN
# Name: CHARGES, dtype: object
#
# **********
#
#
# TAX
#
# count     955
# unique    736
# top         0
# freq       37
# Name: TAX, dtype: object
#
# 7912     NaN
# 22156    NaN
# 30890    NaN
# Name: TAX, dtype: object
#
# **********
#
#
# BEDS
#
# count     817
# unique     18
# top         4
# freq      218
# Name: BEDS, dtype: object
#
# 22709    NaN
# 39626    NaN
# 32624    NaN
# Name: BEDS, dtype: object
#
# **********
#
#
# BATHS
#
# count    826.000000
# mean       2.355932
# std        1.301447
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max       16.000000
# Name: BATHS, dtype: float64
#
# 38210   NaN
# 9812    NaN
# 29641   NaN
# Name: BATHS, dtype: float64
#
# **********
#
#
# WEEKS
#
# count     10751
# unique       53
# top          12
# freq      10447
# Name: WEEKS, dtype: object
#
# 34150    NaN
# 35603    NaN
# 17980    NaN
# Name: WEEKS, dtype: object
#
# **********
#
#
# TELEPHONE
#
# count             37108
# unique               33
# top       PropertyShark
# freq              36515
# Name: TELEPHONE, dtype: object
#
# 11558    PropertyShark
# 36128    PropertyShark
# 21881    PropertyShark
# Name: TELEPHONE, dtype: object
#
# **********
#
#
# CONTACT
#
# count             198
# unique             82
# top       Paul Murphy
# freq               23
# Name: CONTACT, dtype: object
#
# 26831    NaN
# 31929    NaN
# 25958    NaN
# Name: CONTACT, dtype: object
#
# **********
#
#
# AGENCY
#
# count          527
# unique          86
# top       Corcoran
# freq           219
# Name: AGENCY, dtype: object
#
# 37573    NaN
# 39388    NaN
# 39930    NaN
# Name: AGENCY, dtype: object
#
# **********
#
#
# ANNUAL $
#
# count          40600
# unique         25288
# top       $37,494.00
# freq              30
# Name: ANNUAL $, dtype: object
#
# 36824    $64,340.00
# 4469     $57,942.00
# 8070     $18,318.00
# Name: ANNUAL $, dtype: object
#
# **********
#
#
# 30yr
#
# count     40357
# unique      268
# top       4.27%
# freq       1124
# Name: 30yr, dtype: object
#
# 31872    2.86%
# 39839    7.12%
# 5636     4.27%
# Name: 30yr, dtype: object
#
# **********
#
#
# ZONING
#
# count     32547
# unique      381
# top         R6B
# freq      10590
# Name: ZONING, dtype: object
#
# 29465    R6B
# 31445    R6B
# 4909     NaN
# Name: ZONING, dtype: object
#
# **********
# /var/folders/n3/q8wb235x57n_sx2q14dsngjr0000gn/T/ipykernel_62878/450818944.py:5: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   {df[col].describe()}\n

# %%
plt.figure(figsize=figsize)
plt.scatter(x=df['UNITS'],
           y=df['FLOORS'])
plt.title('Units vs Floors')
plt.xlabel('Units')
plt.ylabel('Floors')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 plt.figure(figsize=figsize)
# ----> 2 plt.scatter(x=df['UNITS'],
#       3            y=df['FLOORS'])
#       4 plt.title('Units vs Floors')
#       5 plt.xlabel('Units')
#
# File /Applications/Anaconda/anaconda3/envs/sklearn/lib/python3.9/site-packages/matplotlib/pyplot.py:2835, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2830 @_copy_docstring_and_deprecators(Axes.scatter)
#    2831 def scatter(
#    2832         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2833         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2834         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2835     __ret = gca().scatter(
#    2836         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2837         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2838         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2839         **({"data": data} if data is not None else {}), **kwargs)
#    2840     sci(__ret)
#    2841     return __ret
#
# File /Applications/Anaconda/anaconda3/envs/sklearn/lib/python3.9/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File /Applications/Anaconda/anaconda3/envs/sklearn/lib/python3.9/site-packages/matplotlib/axes/_axes.py:4578, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4468 """
#    4469 A scatter plot of *y* vs. *x* with varying marker size and/or color.
#    4470
#    (...)
#    4575
#    4576 """
#    4577 # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4578 x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4579 # np.ma.ravel yields an ndarray, not a masked array,
#    4580 # unless its argument is a masked array.
#    4581 x = np.ma.ravel(x)
#
# File /Applications/Anaconda/anaconda3/envs/sklearn/lib/python3.9/site-packages/matplotlib/axes/_base.py:2551, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2547     # Update from data if axis is already set but no unit is set yet.
#    2548     if (axis is not None and
#    2549             data is not None and
#    2550             not axis._have_units_and_converter()):
# -> 2551         axis.update_units(data)
#    2552 for axis_name, axis in axis_map.items():
#    2553     # Return if no axis is set.
#    2554     if axis is None:
#
# File /Applications/Anaconda/anaconda3/envs/sklearn/lib/python3.9/site-packages/matplotlib/axis.py:1670, in Axis.update_units(self, data)
#    1668 neednew = self.converter != converter
#    1669 self.converter = converter
# -> 1670 default = self.converter.default_units(data, self)
#    1671 if default is not None and self.units is None:
#    1672     self.set_units(default)
#
# File /Applications/Anaconda/anaconda3/envs/sklearn/lib/python3.9/site-packages/matplotlib/category.py:105, in StrCategoryConverter.default_units(data, axis)
#     103 # the conversion call stack is default_units -> axis_info -> convert
#     104 if axis.units is None:
# --> 105     axis.set_units(UnitData(data))
#     106 else:
#     107     axis.units.update(data)
#
# File /Applications/Anaconda/anaconda3/envs/sklearn/lib/python3.9/site-packages/matplotlib/category.py:181, in UnitData.__init__(self, data)
#     179 self._counter = itertools.count()
#     180 if data is not None:
# --> 181     self.update(data)
#
# File /Applications/Anaconda/anaconda3/envs/sklearn/lib/python3.9/site-packages/matplotlib/category.py:216, in UnitData.update(self, data)
#     213 convertible = True
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# --> 216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#     219         convertible = self._str_is_convertible(val)
#
# File /Applications/Anaconda/anaconda3/envs/sklearn/lib/python3.9/site-packages/matplotlib/_api/__init__.py:93, in check_isinstance(_types, **kwargs)
#      91     names.remove("None")
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %% [markdown]
# Next plot example is below:

# %%
# make a bar plot for all but location

plt.subplots(5,2,figsize = (15,15))

for index, col in enumerate(df.select_dtypes('object').columns[:-1]):
    
    plt.subplot(5,2,index + 1)
    df[col].value_counts().sort_values(ascending = False).plot(kind = 'barh',color = 'cornflowerblue')
    plt.title(f"row count {col} status")
    

plt.tight_layout()
plt.show()
